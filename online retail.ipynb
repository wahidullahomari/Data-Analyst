# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel(r'C:\Users\wahid\OneDrive\Documents\programming\PYTHON\DA python\Online Retail.xlsx')

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df = data.copy()

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df['InvoiceNo'] = pd.to_numeric(df['InvoiceNo'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    532618 non-null  float64
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#            InvoiceNo       Quantity                    InvoiceDate  \
# count  532618.000000  541909.000000                         541909
# mean   559965.752027       9.552250  2011-07-04 13:34:57.156386048
# min    536365.000000  -80995.000000            2010-12-01 08:26:00
# 25%    547906.000000       1.000000            2011-03-28 11:34:00
# 50%    560688.000000       3.000000            2011-07-19 17:17:00
# 75%    571841.000000      10.000000            2011-10-19 11:27:00
# max    581587.000000   80995.000000            2011-12-09 12:50:00
# std     13428.417281     218.081158                            NaN
#
#            UnitPrice     CustomerID
# count  541909.000000  406829.000000
# mean        4.611114   15287.690570
# min    -11062.060000   12346.000000
# 25%         1.250000   13953.000000
# 50%         2.080000   15152.000000
# 75%         4.130000   16791.000000
# max     38970.000000   18287.000000
# std        96.759853    1713.600303

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# InvoiceNo        9291
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df['InvoiceNo'].fillna(df['InvoiceNo'].mean())
# Out:
# 0         536365.0
# 1         536365.0
# 2         536365.0
# 3         536365.0
# 4         536365.0
#             ...
# 541904    581587.0
# 541905    581587.0
# 541906    581587.0
# 541907    581587.0
# 541908    581587.0
# Name: InvoiceNo, Length: 541909, dtype: float64

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df['Description'] = df['Description'].fillna('uknown')

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df['CustomerID'].fillna(df['CustomerID'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0        536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365.0     71053                  WHITE METAL LANTERN         6
# 2        536365.0    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...       ...                                  ...       ...
# 541904   581587.0     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905   581587.0     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906   581587.0     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907   581587.0     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908   581587.0     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.duplicated().sum()
# Out:
# 5268

# %%
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#            InvoiceNo       Quantity                    InvoiceDate  \
# count  526054.000000  526054.000000                         526054
# mean   559946.363773      10.730874  2011-07-04 13:30:39.720940800
# min    536365.000000       1.000000            2010-12-01 08:26:00
# 25%    547897.000000       1.000000            2011-03-28 11:36:00
# 50%    560601.000000       4.000000            2011-07-20 01:02:30
# 75%    571748.000000      11.000000            2011-10-19 11:13:00
# max    581587.000000   80995.000000            2011-12-09 12:50:00
# std     13418.938766     157.591838                            NaN
#
#            UnitPrice     CustomerID
# count  526054.000000  526054.000000
# mean        3.871747   15287.723607
# min    -11062.060000   12346.000000
# 25%         1.250000   14382.000000
# 50%         2.080000   15287.690570
# 75%         4.130000   16242.000000
# max     13541.330000   18287.000000
# std        42.016560    1480.587664

# %% [markdown]
# ## EDA

# %%
## negative numbers from quantity and unitprice 
returns = df[df['Quantity'] < 0]

# %%
df = df[(df['Quantity'] > 0 ) & (df['UnitPrice'] > 0 )]

# %%
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0        536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365.0     71053                  WHITE METAL LANTERN         6
# 2        536365.0    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...       ...                                  ...       ...
# 541904   581587.0     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905   581587.0     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906   581587.0     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907   581587.0     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908   581587.0     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
## create total price of each transaction

df['totalprice'] = df['Quantity'] * df['UnitPrice']

# %%
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0        536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365.0     71053                  WHITE METAL LANTERN         6
# 2        536365.0    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...       ...                                  ...       ...
# 541904   581587.0     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905   581587.0     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906   581587.0     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907   581587.0     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908   581587.0     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
df['Description'].value_counts().head(10)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2315
# JUMBO BAG RED RETROSPOT               2112
# REGENCY CAKESTAND 3 TIER              2009
# PARTY BUNTING                         1700
# LUNCH BAG RED RETROSPOT               1581
# ASSORTED COLOUR BIRD ORNAMENT         1476
# SET OF 3 CAKE TINS PANTRY DESIGN      1392
# PACK OF 72 RETROSPOT CAKE CASES       1352
# LUNCH BAG  BLACK SKULL.               1301
# NATURAL SLATE HEART CHALKBOARD        1255
# Name: count, dtype: int64

# %%
## total spending per customers

customer_spending = df.groupby('CustomerID')['totalprice'].sum().sort_values(ascending =False)

# %%
customer_spending.head(10)
# Out:
# CustomerID
# 15287.69057    1732777.79
# 14646.00000     280206.02
# 18102.00000     259657.30
# 17450.00000     194390.79
# 16446.00000     168472.50
# 14911.00000     143711.17
# 12415.00000     124914.53
# 14156.00000     117210.08
# 17511.00000      91062.38
# 16029.00000      80850.84
# Name: totalprice, dtype: float64

# %%
## best products 

top_product = df.groupby('Description')['Quantity'].sum().sort_values(ascending = False)

# %%
top_product.head(10)
# Out:
# Description
# PAPER CRAFT , LITTLE BIRDIE           80995
# MEDIUM CERAMIC TOP STORAGE JAR        78033
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     54951
# JUMBO BAG RED RETROSPOT               48375
# WHITE HANGING HEART T-LIGHT HOLDER    37876
# POPCORN HOLDER                        36749
# PACK OF 72 RETROSPOT CAKE CASES       36396
# ASSORTED COLOUR BIRD ORNAMENT         36362
# uknown                                32547
# RABBIT NIGHT LIGHT                    30739
# Name: Quantity, dtype: int64

# %%
df['Month'] = df['InvoiceDate'].dt.to_period('M')

# %%
## Monthly Revenue 

monthly_revenue = df.groupby('Month')['totalprice'].sum()
monthly_revenue
# Out:
# Month
# 2010-12     821452.730
# 2011-01     689811.610
# 2011-02     522545.560
# 2011-03     716215.260
# 2011-04     536968.491
# 2011-05     769296.610
# 2011-06     760547.010
# 2011-07     718076.121
# 2011-08     735717.260
# 2011-09    1056435.192
# 2011-10    1151263.730
# 2011-11    1503866.780
# 2011-12     637790.330
# Freq: M, Name: totalprice, dtype: float64

# %% [markdown]
# ## Visualization

# %%
import matplotlib 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (12,6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
plt.figure(figsize=(10, 6))
plt.title('monthly_revenue')
plt.xlabel('Month')
plt.ylabel('totalprice')
plt.xticks(rotation=75)
sns.barplot(monthly_revenue, color='skyblue', edgecolor='black');

# %%
# Top 10 products by quantity sold
top_products = data.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
top_products.plot(kind='barh', color='salmon', edgecolor='black')
plt.title('Top 10 Products Sold', fontsize=16)
plt.xlabel('Total Quantity Sold', fontsize=12)
plt.ylabel('Product Description', fontsize=12)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
top_countries = df.nlargest(10, 'totalprice')

# %%
plt.figure(figsize=(8,4))
plt.title('Country with high totalprice')
sns.barplot(x='totalprice', y='Country', data=top_countries)
# Out:
# <Axes: title={'center': 'Country with high totalprice'}, xlabel='totalprice', ylabel='Country'>

# %%
plt.figure(figsize=(12,6))
plt.title('Heatmap')
sns.heatmap(df[['Quantity', 'UnitPrice', 'totalprice']].corr(), annot=True, cmap='coolwarm');

# %%
plt.figure(figsize=(8,4))
plt.title('UnitPrice and totalprice')
plt.xticks(rotation=75)
sns.barplot(x='UnitPrice', y='totalprice', data=total_price)
# Out:
# <Axes: title={'center': 'UnitPrice and totalprice'}, xlabel='UnitPrice', ylabel='totalprice'>

# %%
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0        536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365.0     71053                  WHITE METAL LANTERN         6
# 2        536365.0    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...       ...                                  ...       ...
# 541904   581587.0     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905   581587.0     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906   581587.0     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907   581587.0     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908   581587.0     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
total_price = df.nlargest(10, 'UnitPrice')

# %%
df.to_csv(r'C:\Users\wahid\OneDrive\Documents\programming\PYTHON\DA python\onlineRetailupdate.csv')
